# %%
# !pip install pixelate
# Out:
# Requirement already satisfied: pixelate in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from pixelate) (0.42.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from pixelate) (9.4.0)

# %%
from PIL import Image
from IPython.display import display
def pixelate(input_file_path, pixel_size):
    image = Image.open(input_file_path)
    image = image.resize((image.size[0] // pixel_size, image.size[1] // pixel_size),Image.NEAREST)
    image = image.resize((image.size[0] * pixel_size, image.size[1] * pixel_size),Image.NEAREST)
    display(image)

# %%
pixelate("/content/kQpFYUU (1).jpg", 3)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1200>
